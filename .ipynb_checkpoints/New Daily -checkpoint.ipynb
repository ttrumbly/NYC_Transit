# %%
import pandas as pd
import numpy as np
sub = pd.read_csv('spring_2017.csv')

# %%
sub['datetime'] = pd.to_datetime(sub['datetime'])

# %%
def is_weekday(row):
    if row < 5:
        return 1
    else: 
        return 0

# %%
sub['weekday'] = sub['datetime'].apply(lambda x: x.weekday())
daily_subway = sub.groupby(['station','linename','weekday'])[['hr4']].sum()/5

daily_subway['daily_traffic'] = daily_subway.hr4
daily_subway = daily_subway.reset_index()
daily_subway['is_weekday'] = daily_subway['weekday'].apply(is_weekday)

# %%
daily_subway.head()
# Out:
#   station linename  weekday      hr4  daily_traffic  is_weekday
# 0    1 AV        L        0  20393.2        20393.2           1
# 1    1 AV        L        1  21430.8        21430.8           1
# 2    1 AV        L        2  19801.8        19801.8           1
# 3    1 AV        L        3  21633.4        21633.4           1
# 4    1 AV        L        4  22874.2        22874.2           1

# %%
daily_subway['stl'] = daily_subway['station'] + ' ' + daily_subway['linename']
sub['stl'] = sub['station'] + ' ' + sub['linename']

# %%
ds2 = daily_subway.groupby(['stl','is_weekday'])[['daily_traffic']].sum().reset_index()

# %%
ds2.head()
# Out:
#         stl  is_weekday  daily_traffic
# 0    1 AV L           0        33148.6
# 1    1 AV L           1       106133.4
# 2  103 ST 1           0        17240.0
# 3  103 ST 1           1        61952.4
# 4  103 ST 6           0        12556.0

# %%
ds2['idx'] = ds2['daily_traffic']/ds2['daily_traffic'].shift(1)
ds2['weekly_traffic'] = ds2['daily_traffic'] + ds2['daily_traffic'].shift(1)

ds3 = ds2[ds2.is_weekday == 1]
ds3 = ds3[['stl','idx','weekly_traffic']].reset_index()
ds3= ds3[['stl','idx','weekly_traffic']]
ds3['scaled_weekday_index'] = ds3['idx']/2.5

ds3['scaled_weekday_index'].replace([np.inf, -np.inf], np.nan,inplace=True)

# %%
ds3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473 entries, 0 to 472
# Data columns (total 4 columns):
# stl                     473 non-null object
# idx                     473 non-null float64
# weekly_traffic          473 non-null float64
# scaled_weekday_index    473 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 14.9+ KB

# %%
ds3.head()
# Out:
#                stl       idx  weekly_traffic  scaled_weekday_index
# 0           1 AV L  3.201746        139282.0              1.280698
# 1         103 ST 1  3.593527         79192.4              1.437411
# 2         103 ST 6  5.137209         77058.8              2.054884
# 3        103 ST BC  6.084143         25964.8              2.433657
# 4  103 ST-CORONA 7  4.399661        117799.0              1.759864

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds3.scaled_weekday_index.isnull().sum()
# Out:
# 0

# %%
ds3['scaled_weekday_index'].nlargest(40)
# Out:
# 459    50.217625
# 395    40.353957
# 251    34.295935
# 323    26.791086
# 383     8.705756
# 325     7.688017
# 179     6.733228
# 385     5.412597
# 350     5.363821
# 221     4.912601
# 376     4.832005
# 96      4.734202
# 109     4.607792
# 88      4.438028
# 174     4.411367
# 173     4.371636
# 182     4.310645
# 183     4.155655
# 405     4.117980
# 187     4.105842
# 191     4.071066
# 343     3.961848
# 196     3.860606
# 224     3.842794
# 269     3.811548
# 123     3.772615
# 282     3.754575
# 6       3.649876
# 108     3.610455
# 368     3.595078
# 265     3.591628
# 202     3.590853
# 74      3.552160
# 242     3.534405
# 10      3.523032
# 165     3.502777
# 185     3.438394
# 105     3.427431
# 434     3.385758
# 30      3.373981
# Name: scaled_weekday_index, dtype: float64

# %%
ds3.iloc[223].stl
# Out:
# 'BROADWAY JCT ACJLZ'

# %%
daily_subway[daily_subway['stl'] == ds3.iloc[108].stl]
# Out:
#         station linename  weekday      hr4  daily_traffic  is_weekday  \
# 756  5 AV/53 ST       EM        0  25193.4        25193.4           1
# 757  5 AV/53 ST       EM        1  27718.0        27718.0           1
# 758  5 AV/53 ST       EM        2  24005.2        24005.2           1
# 759  5 AV/53 ST       EM        3  26375.2        26375.2           1
# 760  5 AV/53 ST       EM        4  25791.0        25791.0           1
# 761  5 AV/53 ST       EM        5   8222.0         8222.0           0
# 762  5 AV/53 ST       EM        6   6079.0         6079.0           0
#
#                stl
# 756  5 AV/53 ST EM
# 757  5 AV/53 ST EM
# 758  5 AV/53 ST EM
# 759  5 AV/53 ST EM
# 760  5 AV/53 ST EM
# 761  5 AV/53 ST EM
# 762  5 AV/53 ST EM

# %%
plt.hist(ds3.weekly_traffic)
# Out:
# (array([351.,  92.,  16.,   6.,   3.,   2.,   1.,   0.,   1.,   1.]),
#  array([  1265.4 ,  87642.66, 174019.92, 260397.18, 346774.44, 433151.7 ,
#         519528.96, 605906.22, 692283.48, 778660.74, 865038.  ]),
#  <a list of 10 Patch objects>)

# %%
ds4 = ds3[ds3['weekly_traffic']>100000]

# %%
plt.hist(ds4.weekly_traffic)
# Out:
# (array([68., 13.,  7.,  4.,  2.,  1.,  0.,  0.,  1.,  1.]),
#  array([100950.8 , 177359.52, 253768.24, 330176.96, 406585.68, 482994.4 ,
#         559403.12, 635811.84, 712220.56, 788629.28, 865038.  ]),
#  <a list of 10 Patch objects>)

# %%
ds4
# Out:
#                               stl         idx  weekly_traffic  \
# 0                          1 AV L    3.201746        139282.0
# 4                 103 ST-CORONA 7    4.399661        117799.0
# 18                     125 ST 456    4.177060        167253.2
# 19                    125 ST ACBD    3.323432        180897.6
# 24                   14 ST 123FLM    4.311352        132299.4
# 25                     14 ST ACEL    4.298806        129360.8
# 26                   14 ST FLM123    5.447866        103470.2
# 27        14 ST-UNION SQ 456LNQRW    3.413482        197969.4
# 28        14 ST-UNION SQ LNQR456W    3.817288        436497.4
# 31                    145 ST ABCD    3.737543        148669.8
# 62                         2 AV F    3.404268        103987.4
# 72                        23 ST 6    7.878508        156331.0
# 73                       23 ST CE    4.971015        135840.6
# 74                       23 ST FM    8.880399        165668.6
# 75                      23 ST NRW    4.408975        148955.6
# 82                        28 ST 6    6.869714        126025.6
# 86                 3 AV-149 ST 25    4.936275        136564.0
# 87                        33 ST 6    6.709383        162757.4
# 89       34 ST-HERALD SQ BDFMNQRW    4.638179        743454.8
# 91             34 ST-PENN STA 123    6.053304        186098.6
# 92          34 ST-PENN STA 123ACE    5.389363        305777.0
# 93             34 ST-PENN STA ACE    4.557777        480479.8
# 99          42 ST-BRYANT PK BDFM7    7.133393        231575.6
# 101  42 ST-PORT AUTH ACENQRS1237W    4.243536        542259.2
# 105           47-50 STS ROCK BDFM    8.568578        324321.2
# 470              2.183085
#
# [97 rows x 4 columns]

# %%
loc = pd.read_csv('nyc_subway_locations.csv')

# %%
loc.head()
# Out:
#    OBJECTID              NAME                                      the_geom  \
# 0         1          Astor Pl  POINT (-73.99106999861966 40.73005400028978)
# 1         2          Canal St  POINT (-74.00019299927328 40.71880300107709)
# 2         3           50th St  POINT (-73.98384899986625 40.76172799961419)
# 3         4         Bergen St  POINT (-73.97499915116808 40.68086213682956)
# 4         5  Pennsylvania Ave  POINT (-73.89488591154061 40.66471445143568)
#
#             LINE
# 0  4-6-6 Express
# 1  4-6-6 Express
# 2            1-2
# 3          2-3-4
# 4            3-4

# %%
loc.LINE.value_counts()
# Out:
# 2-5                26
# L                  24
# F                  21
# 1                  20
# A-C                18
# J-Z                15
# A                  14
# 4-6-6 Express      14
# 4                  13
# D                  13
# G                  12
# A-S                12
# Q                  12
# 1-2                12
# B-D                11
# E-M-R              11
# 7-7 Express        11
# 3-4                10
# 2-3                10
# 7                  10
# N                   9
# 6                   9
# 6-6 Express         9
# N-Q-R-W             9
# F-G                 8
# A-C-E               8
# A-B-C               8
# B-Q                 7
# M                   7
# J                   7
#                    ..
# N-R                 5
# 4-5                 5
# B-D-F-M             5
# D-N-R               5
# R                   4
# J-M                 3
# E-M                 3
# 2-3-4-5             3
# J-M-Z               3
# 2-3-4               3
# A-B-C-D             3
# E-F                 3
# F-M                 2
# E-J-Z               2
# E                   2
# E-F-M-R             2
# N-R-W               2
# F-Q                 2
# 3                   2
# B-D-N-Q-R           1
# 2                   1
# 7-7 Express-N-W     1
# A-C-F               1
# B-Q-S               1
# N-Q                 1
# B-D-E               1
# D-N-Q-R             1
# A-C-G               1
# D-F-N-Q             1
# A-C-S               1
# Name: LINE, Length: 66, dtype: int64

# %%
loc[loc['LINE'] == '2-5']
# Out:
#      OBJECTID                             NAME  \
# 17         18                       Freeman St
# 18         19                    Intervale Ave
# 38         39                      Pelham Pkwy
# 39         40                      Gun Hill Rd
# 40         41              Nereid Ave (238 St)
# 42         43                       Simpson St
# 43         44                  Bronx Park East
# 44         45                      Winthrop St
# 86         87                         233rd St
# 129       130                       Beverly Rd
# 130       131                       Church Ave
# 131       132                      Newkirk Ave
# 132       133  Brooklyn College - Flatbush Ave
# 133       134                      Sterling St
# 247       248                         225th St
# 252       253                      Jackson Ave
# 253       254                     Prospect Ave
# 255       256                         174th St
# 256       257                     Allerton Ave
# 271       272     West Farms Sq - E Tremont Av
# 272       273                         219th St
# 275       276                        Burke Ave
# 284       285                       E 180th St
# 288       289       149th St - Grand Concourse
# 289       290               3rd Ave - 149th St
# 454       455                     President St
#
#                                           the_geom LINE
# 17   POINT (-73.89175225349464 40.829987446384116)  2-5
# 18   POINT (-73.89661738461646 40.822142131170786)  2-5
# 38     POINT (-73.86748067850041 40.8571924091606)  2-5
# 39   POINT (-73.86613410538703 40.877839385172024)  2-5
# 40    POINT (-73.8543153107622 40.898286515575286)  2-5
# 42   POINT (-73.89306639507903 40.823976841237396)  2-5
# 43   POINT (-73.86835609178098 40.848768666338934)  2-5
# 44    POINT (-73.95007934590994 40.65665931376077)  2-5
# 86    POINT (-73.85736239521543 40.89314324138378)  2-5
# 129   POINT (-73.94884798381702 40.64512351894373)  2-5
# 130    POINT (-73.94945514035334 40.6508606878022)  2-5
# 131   POINT (-73.94829990822407 40.63999124275311)  2-5
# 132   POINT (-73.94754120734406 40.63284240700742)  2-5
# 133    POINT (-73.95072891124937 40.6627729934283)  2-5
# 247   POINT (-73.86021461772737 40.88802825863786)  2-5
# 252    POINT (-73.9077019387083 40.81643746686396)  2-5
# 253   POINT (-73.90177778730917 40.81948726483844)  2-5
# 255  POINT (-73.88769359812888 40.837195550170605)  2-5
# 256   POINT (-73.86723422851625 40.86548337793927)  2-5
# 271   POINT (-73.87996127877184 40.84020763241799)  2-5
# 272   POINT (-73.8625097078866 40.883887974625274)  2-5
# 275   POINT (-73.86705361747603 40.87125880254771)  2-5
# 284    POINT (-73.87334609510884 40.8418630412186)  2-5
# 288   POINT (-73.92672247438611 40.81833014409742)  2-5
# 289  POINT (-73.91779152760981 40.816029252510006)  2-5
# 454  POINT (-73.95058920022207 40.667883603536815)  2-5

# %%
ds4.scaled_weekday_index.nlargest(10)
# Out:
# 458    1275.827027
# 142       6.567872
# 113       4.780640
# 104       3.920389
# 98        3.918818
# 73        3.770556
# 241       3.743042
# 351       3.410756
# 399       3.369057
# 107       3.194070
# Name: scaled_weekday_index, dtype: float64

# %%
def cleanline(row):
    l = row['LINE']
    
    l = l.replace('6 Express' , '')
    l = l.replace('7 Express' , '')
    l = l.replace('-' , '')
    
    l = l.replace(' ' , '')
    return l

# %%
loc['newline'] = loc.apply(cleanline, axis=1)

# %%
loc['newline']
# Out:
# 0         46
# 1         46
# 2         12
# 3        234
# 4         34
# 5          1
# 6        ABC
# 7         AC
# 8        EMR
# 9        EMR
# 10       JMZ
# 11        JZ
# 12        JZ
# 13        JZ
# 14     BDNQR
# 15        AS
# 16        AS
# 17        25
# 18        25
# 19        BD
# 20        BD
# 21        BD
# 22         7
# 23         7
# 24         7
# 25         6
# 26         6
# 27         6
# 28       456
# 29         6
#        ...
# 443      ACE
# 444       34
# 445       23
# 446       AC
# 447       AC
# 448        M
# 449       46
# 450      456
# 451        F
# 452       AC
# 453       AC
# 454       25
# 455        4
# 456       46
# 457       46
# 458      ACS
# 459       AS
# 460        Q
# 461       46
# 462        6
# 463       12
# 464       AS
# 465        7
# 466       46
# 467      456
# 468     DFNQ
# 469        7
# 470        Q
# 471        Q
# 472        Q
# Name: newline, Length: 473, dtype: object

# %%
import fnmatch

# %%
w = '7-7 Express'

w.replace('7 Express', '')
# Out:
# '7-'

# %%
def cleanname(row):
    l = row['NAME']
    l = l.upper()
    l = l.split(' ')
    if 'ST' in l:
        r = l.remove('ST')
        l = ' '.join(r)
        return l
    else:
        r = ' '.join(l)
        return r

# %%
loc['newname'] = loc.apply(cleanname,axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-ebe257fe47b2> in <module>()
# ----> 1 loc['newname'] = loc.apply(cleanname,axis=1)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
#    4879                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4971             try:
#    4972                 for i, v in enumerate(series_gen):
# -> 4973                     results[i] = func(v)
#    4974                     keys.append(v.name)
#    4975             except Exception as e:
#
# <ipython-input-98-e516296cb159> in cleanname(row)
#       5     if 'ST' in l:
#       6         r = l.remove('ST')
# ----> 7         l = ' '.join(r)
#       8         return l
#       9     else:
#
# TypeError: ('can only join an iterable', 'occurred at index 1')

# %%
loc.head()
# Out:
#    OBJECTID              NAME                                      the_geom  \
# 0         1          Astor Pl  POINT (-73.99106999861966 40.73005400028978)
# 1         2          Canal St  POINT (-74.00019299927328 40.71880300107709)
# 2         3           50th St  POINT (-73.98384899986625 40.76172799961419)
# 3         4         Bergen St  POINT (-73.97499915116808 40.68086213682956)
# 4         5  Pennsylvania Ave  POINT (-73.89488591154061 40.66471445143568)
#
#             LINE newline newname
# 0  4-6-6 Express      46
# 1  4-6-6 Express      46
# 2            1-2      12
# 3          2-3-4     234
# 4            3-4      34

# %%
test = 'Astor Pl'

# %%
t = test.upper()

# %%
s = t.split(' ')

# %%
s
# Out:
# ['ASTOR', 'PL']

# %%
' '.join(s)
# Out:
# 'ASTOR PL'

# %%
loc.sort_values(['NAME','LINE'])[100:120]
# Out:
#      OBJECTID                             NAME  \
# 348       349  47th-50th Sts - Rockefeller Ctr
# 353       354                          49th St
# 381       382                  4th Av - 9th St
# 373       374                  4th Av - 9th St
# 2           3                          50th St
# 346       347                          50th St
# 310       311                          50th St
# 84         85                          51st St
# 235       236                          52nd St
# 390       391                          53rd St
# 61         62                          55th St
# 349       350                          57th St
# 354       355                          57th St
# 386       387                          59th St
# 93         94        59th St - Columbus Circle
# 352       353        59th St - Columbus Circle
# 141       142                5th Ave - 53rd St
# 355       356                5th Ave - 59th St
# 465       466              5th Ave - Bryant Pk
# 322       323                          62nd St
#
#                                           the_geom           LINE newline  \
# 348   POINT (-73.98133100227702 40.75864100159815)        B-D-F-M    BDFM
# 353  POINT (-73.98420956591096 40.759801973870694)        N-Q-R-W    NQRW
# 381  POINT (-73.98830199974512 40.670846666842756)          D-N-R     DNR
# 373   POINT (-73.98977899938897 40.67027166728493)            F-G      FG
# 2     POINT (-73.98384899986625 40.76172799961419)            1-2      12
# 346   POINT (-73.98598400026407 40.76245599925997)          A-C-E     ACE
# 310   POINT (-73.9946587805514 40.636260890961395)              D       D
# 84    POINT (-73.97192000069982 40.75710699989316)  4-6-6 Express      46
# 235  POINT (-73.91254899891254 40.744149001021576)              7       7
# 390   POINT (-74.01403399986317 40.64506866735981)            N-R      NR
# 61    POINT (-73.99534882595742 40.63147876093745)              D       D
# 349   POINT (-73.97736800085171 40.76408500081713)              F       F
# 354   POINT (-73.98072973372128 40.76456552501829)        N-Q-R-W    NQRW
# 386    POINT (-74.01788099953987 40.6413616662838)            N-R      NR
# 93    POINT (-73.98192900232715 40.76824700063689)            1-2      12
# 352  POINT (-73.98164872301398 40.768249531776064)        A-B-C-D    ABCD
# 141    POINT (-73.9752485052734 40.76008683231326)            E-M      EM
# 355  POINT (-73.97334700047045 40.764810999755284)          N-R-W     NRW
# 465   POINT (-73.98196299856706 40.75382100064824)    7-7 Express       7
# 322  POINT (-73.99685724994863 40.626224462922195)              D       D
#
#     newname
# 348     NaN
# 353     NaN
# 381     NaN
# 373     NaN
# 2       NaN
# 346     NaN
# 310     NaN
# 84      NaN
# 235     NaN
# 390     NaN
# 61      NaN
# 349     NaN
# 354     NaN
# 386     NaN
# 93      NaN
# 352     NaN
# 141     NaN
# 355     NaN
# 465     NaN
# 322     NaN

# %%
ds3[100:125]
# Out:
#                               stl          idx  weekly_traffic  \
# 100  42 ST-PORT AUTH ACENQRS1237W     4.660078        566421.0
# 101                       45 ST R     4.768596         37767.0
# 102              46 ST BLISS ST 7     4.129554         76179.0
# 103                      46 ST MR     4.727871         51379.0
# 104           47-50 STS ROCK BDFM     9.800973        328436.0
# 105                    49 ST NQRW     4.413060        160573.0
# 106               4AV-9 ST DFGMNR     5.529542         50284.0
# 107                 5 AV/53 ST EM     7.985176        151526.0
# 108               5 AV/59 ST NQRW  4054.736842         77059.0
# 109                   5 AVE 7BDFM     7.283682         73352.0
# 110                       50 ST 1     4.938061        154253.0
# 111                      50 ST CE     3.601196        123059.0
# 112                       50 ST D     5.649001         15306.0
# 113                       51 ST 6    11.951600        112925.0
# 114                       52 ST 7     4.150909         36829.0
# 115                       53 ST R     5.096363         38718.0
# 116                       55 ST D     6.136638         10655.0
# 117                       57 ST F     4.073278         91111.0
# 118               57 ST-7 AV NQRW     5.220945        207201.0
# 119                 59 ST 456NQRW     4.404452        243022.0
# 120          59 ST COLUMBUS 1ABCD     4.536370         84712.0
# 121          59 ST COLUMBUS ABCD1     4.556248        324546.0
# 122                 59 ST NQR456W  1060.068966         61542.0
# 123                     59 ST NRW     4.194797         71283.0
# 124                   6 AV FLM123     4.223932         36672.0
#
#      scaled_weekday_index
# 100              1.864031
# 101              1.907439
# 102              1.651821
# 103              1.891148
# 104              3.920389
# 105              1.765224
# 106              2.211817
# 107              3.194070
# 108           1621.894737
# 109              2.913473
# 110              1.975224
# 111              1.440479
# 112              2.259600
# 113              4.780640
# 114              1.660364
# 115              2.038545
# 116              2.454655
# 117              1.629311
# 118              2.088378
# 119              1.761781
# 120              1.814548
# 121              1.822499
# 122            424.027586
# 123              1.677919
# 124              1.689573

# %%
loc[loc['LINE'] == 'L']
# Out:
#      OBJECTID                      NAME  \
# 71         72                Lorimer St
# 72         73                Sutter Ave
# 73         74                Wilson Ave
# 145       146                   1st Ave
# 148       149                  Grand St
# 149       150                Graham Ave
# 150       151               Bedford Ave
# 151       152              Montrose Ave
# 193       194              Atlantic Ave
# 210       211                 Halsey St
# 211       212     Myrtle - Wyckoff Aves
# 215       216               Livonia Ave
# 218       219  Canarsie - Rockaway Pkwy
# 219       220                E 105th St
# 222       223              New Lots Ave
# 234       235                DeKalb Ave
# 281       282       Bushwick - Aberdeen
# 282       283         Broadway Junction
# 304       305              Jefferson St
# 305       306                Morgan Ave
# 382       383                   3rd Ave
# 383       384        Union Sq - 14th St
# 441       442                   6th Ave
# 442       443                   8th Ave
#
#                                           the_geom LINE newline newname
# 71    POINT (-73.95024799996972 40.71407200064717)    L       L     NaN
# 72     POINT (-73.9019160004208 40.66914500061398)    L       L     NaN
# 73    POINT (-73.90395860491864 40.68886654246024)    L       L     NaN
# 145   POINT (-73.98168087489128 40.73097497580066)    L       L     NaN
# 148   POINT (-73.94049699874644 40.71157600064823)    L       L     NaN
# 149  POINT (-73.94394399869037 40.714575998363635)    L       L     NaN
# 150   POINT (-73.95666499806525 40.71717399858899)    L       L     NaN
# 151   POINT (-73.93979284713505 40.70739106438455)    L       L     NaN
# 193    POINT (-73.9030969995401 40.67534466640805)    L       L     NaN
# 210   POINT (-73.90393400118631 40.69551800114878)    L       L     NaN
# 211   POINT (-73.9109757182647 40.699471062427136)    L       L     NaN
# 215   POINT (-73.90056237226057 40.66405727094644)    L       L     NaN
# 218   POINT (-73.90185000017287 40.64665366739528)    L       L     NaN
# 219   POINT (-73.89954769388724 40.65046878544699)    L       L     NaN
# 222   POINT (-73.89927796057142 40.65891477368527)    L       L     NaN
# 234   POINT (-73.91823200219723 40.70369299961644)    L       L     NaN
# 281   POINT (-73.90526176305106 40.68286062551184)    L       L     NaN
# 282   POINT (-73.90311757920684 40.67845624842869)    L       L     NaN
# 304   POINT (-73.9229130000312 40.706606665988716)    L       L     NaN
# 305   POINT (-73.93314700024209 40.70615166680729)    L       L     NaN
# 382   POINT (-73.98575000112093 40.73269099971662)    L       L     NaN
# 383   POINT (-73.99066976901818 40.73476331217923)    L       L     NaN
# 441   POINT (-73.99775078874781 40.73774146981052)    L       L     NaN
# 442   POINT (-74.00257800104762 40.73977666638199)    L       L     NaN

# %%
map_dict = {'1st': '1', '2nd': '2', '3rd' : '3', '4th':'4','5th': '5','6th': '6','7th':'7','8th': '8','9th':'9',
            '0th':'0'}
loc.newname = loc['NAME'].map(map_dict)

# %%
ds4['scaled_weekday_index'].nlargest(10)
# Out:
# 459    50.217625
# 108     3.610455
# 74      3.552160
# 242     3.534405
# 105     3.427431
# 241     3.345919
# 131     3.338626
# 400     3.157615
# 72      3.151403
# 217     2.981625
# Name: scaled_weekday_index, dtype: float64

# %%
ds4['weekly_traffic'].nlargest(10)
# Out:
# 310    865038.0
# 89     743454.8
# 101    542259.2
# 93     480479.8
# 28     436497.4
# 444    393660.2
# 300    360186.6
# 122    352746.0
# 287    342280.8
# 105    324321.2
# Name: weekly_traffic, dtype: float64

# %%
ds4.loc[459,'scaled_weekday_index']
# Out:
# 5.0

# %%
ds4
# Out:
#                               stl         idx  weekly_traffic  \
# 0                          1 AV L    3.201746        139282.0
# 4                 103 ST-CORONA 7    4.399661        117799.0
# 18                     125 ST 456    4.177060        167253.2
# 19                    125 ST ACBD    3.323432        180897.6
# 24                   14 ST 123FLM    4.311352        132299.4
# 25                     14 ST ACEL    4.298806        129360.8
# 26                   14 ST FLM123    5.447866        103470.2
# 27        14 ST-UNION SQ 456LNQRW    3.413482        197969.4
# 28        14 ST-UNION SQ LNQR456W    3.817288        436497.4
# 31                    145 ST ABCD    3.737543        148669.8
# 62                         2 AV F    3.404268        103987.4
# 72                        23 ST 6    7.878508        156331.0
# 73                       23 ST CE    4.971015        135840.6
# 74                       23 ST FM    8.880399        165668.6
# 75                      23 ST NRW    4.408975        148955.6
# 82                        28 ST 6    6.869714        126025.6
# 306              1.351323
# 308              1.802443
# 310              2.832138
# 312              2.109198
# 330              2.798077
# 331              2.526063
# 333              2.449349
# 337              1.426711
# 338              2.018257
# 339              1.379967
# 341              2.369461
# 342              2.198305
# 352              2.977203
# 353              1.514395
# 373              1.527686
# 392              1.576055
# 400              3.157615
# 402              2.567190
# 438              1.861685
# 442              2.238638
# 443              1.108413
# 444              1.684893
# 450              1.522449
# 456              1.311358
# 459              5.000000
# 460              2.743324
# 463              2.517490
# 468              1.701097
# 470              2.183085
#
# [97 rows x 4 columns]

# %%
plt.barh(1,ds4['scaled_weekday_index'].nlargest(10),height=1)
# Out:
# <BarContainer object of 10 artists>

# %%
ds4['scaled_weekday_index'].nlargest(10)
# Out:
# 459    5.000000
# 108    3.610455
# 74     3.552160
# 242    3.534405
# 105    3.427431
# 241    3.345919
# 131    3.338626
# 400    3.157615
# 72     3.151403
# 217    2.981625
# Name: scaled_weekday_index, dtype: float64

# %%
for i in ds4['scaled_weekday_index'].nlargest(10):
    print(i)
# Out:
# 5.0
# 3.610455212922173
# 3.5521595476937393
# 3.5344050695069624
# 3.4274310800604226
# 3.3459187273485362
# 3.3386258800679776
# 3.1576153217330374
# 3.1514033553311607
# 2.9816250112334863

# %%
large_weekday = ds4.isin(ds4['scaled_weekday_index'].nlargest(10))

# %%
large_weekday
# Out:
#        stl    idx  weekly_traffic  scaled_weekday_index
# 0    False  False           False                 False
# 4    False  False           False                 False
# 18   False  False           False                 False
# 19   False  False           False                 False
# 24   False  False           False                 False
# 25   False  False           False                 False
# 26   False  False           False                 False
# 27   False  False           False                 False
# 28   False  False           False                 False
# 31   False  False           False                 False
# 62   False  False           False                 False
# 72   False  False           False                  True
# 73   False  False           False                 False
# 74   False  False           False                  True
# 75   False  False           False                 False
# 82   False  False           False                 False
# 86   False  False           False                 False
# 87   False  False           False                 False
# 89   False  False           False                 False
# 91   False  False           False                 False
# 92   False  False           False                 False
# 93   False  False           False                 False
# 99   False  False           False                 False
# 101  False  False           False                 False
# 105  False  False           False                  True
# 106  False  False           False                 False
# 108  False  False           False                  True
# 111  False  False           False                 False
# 112  False  False           False                 False
# 114  False  False           False                 False
# ..     ...    ...             ...                   ...
# 301  False  False           False                 False
# 306  False  False           False                 False
# 308  False  False           False                 False
# 310  False  False           False                 False
# 312  False  False           False                 False
# 330  False  False           False                 False
# 331  False  False           False                 False
# 333  False  False           False                 False
# 337  False  False           False                 False
# 338  False  False           False                 False
# 339  False  False           False                 False
# 341  False  False           False                 False
# 342  False  False           False                 False
# 352  False  False           False                 False
# 353  False  False           False                 False
# 373  False  False           False                 False
# 392  False  False           False                 False
# 400  False  False           False                  True
# 402  False  False           False                 False
# 438  False  False           False                 False
# 442  False  False           False                 False
# 443  False  False           False                 False
# 444  False  False           False                 False
# 450  False  False           False                 False
# 456  False  False           False                 False
# 459  False  False           False                  True
# 460  False  False           False                 False
# 463  False  False           False                 False
# 468  False  False           False                 False
# 470  False  False           False                 False
#
# [97 rows x 4 columns]

# %%
ds5 = ds4.sort_values(by = 'scaled_weekday_index',ascending=False)[:10]

# %%
ds3[ds3['stl']=='BROADWAY JCT ACJLZ']
# Out:
#                     stl       idx  weekly_traffic  scaled_weekday_index
# 223  BROADWAY JCT ACJLZ  2.677154         58997.0              1.070862

# %%
import seaborn as sns

fig,ax = plt.subplots(figsize=(10,6))

stations = ds5.stl
y_pos = np.arange(len(stations))
traffic = ds5.weekly_traffic


ax = sns.barplot(traffic,stations,palette='rocket')
ax.set(ylabel = 'Stations',

xlabel=('Weekly Entries'),
title=('Stations with at least 3x ridership on Weekdays'))
# Out:
# [Text(0,0.5,'Stations'),
#  Text(0.5,0,'Weekly Entries'),
#  Text(0.5,1,'Stations with at least 3x ridership on Weekdays')]

# %%
ds6 = ds4.sort_values(by = 'scaled_weekday_index',ascending=True)[:10]

# %%
ttst=sub[sub['stl'] == '23 ST 6'].set_index(['datetime'])

# %%
sub['time'] = sub['datetime'].dt.time

# %%
resample_ttst = ttst['hr4'].resample('4H',label='left').sum().reset_index()

# %%
plt.plot(resample_ttst['datetime'],resample_ttst['hr4'])

# %%
resample_ttst['time'] = resample_ttst['datetime'].dt.hour

# %%
resample_ttst['weekday'] = resample_ttst['datetime'].dt.weekday

# %%
resample_ttst['bday'] = resample_ttst['weekday'].apply(is_weekday)

# %%
n = resample_ttst.groupby(['weekday','time'])['hr4'].mean().reset_index()

# %%
for i in range(7):
    plt.plot(n[n['weekday']==i]['time'],n[n['weekday']==i]['hr4'])

# %%
fig,ax = plt.subplots()

stations = ds6.stl
y_pos = np.arange(len(stations))
traffic = ds6.weekly_traffic


ax = sns.barplot(traffic,stations,palette='Greens')
ax.set(ylabel = 'Stations',

xlabel=('Weekly Entries'),
title=('Stations with at least 3x ridership on Weekdays'))
# Out:
# [Text(0,0.5,'Stations'),
#  Text(0.5,0,'Weekly Entries'),
#  Text(0.5,1,'Stations with at least 3x ridership on Weekdays')]

# %%
sub
# Out:
#         Unnamed: 0   c/a  unit       scp    station linename division  \
# 0                0  H007  R248  00-00-00       1 AV        L      BMT
# 1                1  H007  R248  00-00-00       1 AV        L      BMT
# 2                2  H007  R248  00-00-00       1 AV        L      BMT
# 3                3  H007  R248  00-00-00       1 AV        L      BMT
# 4                4  H007  R248  00-00-00       1 AV        L      BMT
# 5                5  H007  R248  00-00-00       1 AV        L      BMT
# 6                6  H007  R248  00-00-00       1 AV        L      BMT
# 7                7  H007  R248  00-00-00       1 AV        L      BMT
# 8                8  H007  R248  00-00-00       1 AV        L      BMT
# 9                9  H007  R248  00-00-00       1 AV        L      BMT
# 10              10  H007  R248  00-00-00       1 AV        L      BMT
# 11              11  H007  R248  00-00-00       1 AV        L      BMT
# 12              12  H007  R248  00-00-00       1 AV        L      BMT
# 13              13  H007  R248  00-00-00       1 AV        L      BMT
# 14              14  H007  R248  00-00-00       1 AV        L      BMT
# 15              15  H007  R248  00-00-00       1 AV        L      BMT
# 16              16  H007  R248  00-00-00       1 AV        L      BMT
# 17              17  H007  R248  00-00-00       1 AV        L      BMT
# 18              18  H007  R248  00-00-00       1 AV        L      BMT
# 4    105  47-50 STS ROCK BDFM    8.568578        324321.2
# 5    241      CHAMBERS ST 123    8.364797        116794.0
# 6    131     68ST-HUNTER CO 6    8.346565        123195.2
# 7    400       PATH NEW WTC 1    7.894038        304638.6
# 8     72              23 ST 6    7.878508        156331.0
# 9    217     BOWLING GREEN 45    7.454063        169329.8
#
#    scaled_weekday_index
# 0              5.000000
# 1              3.610455
# 2              3.552160
# 3              3.534405
# 4              3.427431
# 5              3.345919
# 6              3.338626
# 7              3.157615
# 8              3.151403
# 9              2.981625

# %%
loc[loc['NAME'].str.contains('World')]
# Out:
#      OBJECTID                NAME  \
# 408       409  World Trade Center
#
#                                          the_geom LINE newline newname
# 408  POINT (-74.00974461517701 40.71256392680817)    E       E     NaN

# %%
l = ['POINT (-74.00909999844257 40.706820999753376)','POINT (-73.9752485052734 40.76008683231326)','POINT (-73.99276500471389 40.742954317826005)','POINT (-74.00858473570133 40.714111000774025)','POINT (-73.98133100227702 40.75864100159815)','POINT (-74.00926600170112 40.71547800011327)','POINT (-73.96387000158042 40.76814100049679)','POINT (-74.00974461517701 40.71256392680817)','POINT (-73.98659900207888 40.739864000474604)','POINT (-74.01400799803432 40.70491399928076)']

# %%
m = np.asarray(l)

# %%
len(m)
# Out:
# 10

# %%
l = ['POINT (-74.00909999844257 40.706820999753376)','POINT (-73.9752485052734 40.76008683231326)','POINT (-73.99276500471389 40.742954317826005)','POINT (-74.00858473570133 40.714111000774025)','POINT (-73.98133100227702 40.75864100159815)','POINT (-74.00926600170112 40.71547800011327)','POINT (-73.96387000158042 40.76814100049679)','POINT (-74.00974461517701 40.71256392680817)','POINT (-73.98659900207888 40.739864000474604)','POINT (-74.01400799803432 40.70491399928076)']
m = np.asarray(l)
ds5['loc'] = m

ds5['lon'] = ds5['loc'].apply(lambda x: float( x.split(' ')[1][1:]))
ds5['lat'] = ds5['loc'].apply(lambda x: float( x.split(' ')[2][:-1]))
ds5.drop(['loc'],axis=1,inplace=True)
ds5
# Out:
#                      stl         idx  weekly_traffic  scaled_weekday_index  \
# 459           WALL ST 23  125.544063        122342.8              5.000000
# 108        5 AV/53 ST EM    9.026138        143383.8              3.610455
# 74              23 ST FM    8.880399        165668.6              3.552160
# 242    CHAMBERS ST ACE23    8.836013        168256.8              3.534405
# 105  47-50 STS ROCK BDFM    8.568578        324321.2              3.427431
# 241      CHAMBERS ST 123    8.364797        116794.0              3.345919
# 131     68ST-HUNTER CO 6    8.346565        123195.2              3.338626
# 400       PATH NEW WTC 1    7.894038        304638.6              3.157615
# 72               23 ST 6    7.878508        156331.0              3.151403
# 217     BOWLING GREEN 45    7.454063        169329.8              2.981625
#
#            lat        lon
# 459  40.706821 -74.009100
# 108  40.760087 -73.975249
# 74   40.742954 -73.992765
# 242  40.714111 -74.008585
# 105  40.758641 -73.981331
# 241  40.715478 -74.009266
# 131  40.768141 -73.963870
# 400  40.712564 -74.009745
# 72   40.739864 -73.986599
# 217  40.704914 -74.014008

# %%
import mplleaflet
plt.scatter(x=ds5['lon'],y=ds5['lat'],s=(ds5['scaled_weekday_index']/3)**2*300,c='green')
mplleaflet.show(tiles='esri_natgeo')

# %%
ds5
# Out:
#                      stl         idx  weekly_traffic  scaled_weekday_index  \
# 459           WALL ST 23  125.544063        122342.8              5.000000
# 108        5 AV/53 ST EM    9.026138        143383.8              3.610455
# 74              23 ST FM    8.880399        165668.6              3.552160
# 242    CHAMBERS ST ACE23    8.836013        168256.8              3.534405
# 105  47-50 STS ROCK BDFM    8.568578        324321.2              3.427431
# 241      CHAMBERS ST 123    8.364797        116794.0              3.345919
# 131     68ST-HUNTER CO 6    8.346565        123195.2              3.338626
# 400       PATH NEW WTC 1    7.894038        304638.6              3.157615
# 72               23 ST 6    7.878508        156331.0              3.151403
# 217     BOWLING GREEN 45    7.454063        169329.8              2.981625
#
#                     lat                 lon
# 459  40.706820999753376  -74.00909999844257
# 108   40.76008683231326   -73.9752485052734
# 74   40.742954317826005  -73.99276500471389
# 242  40.714111000774025  -74.00858473570133
# 105   40.75864100159815  -73.98133100227702
# 241   40.71547800011327  -74.00926600170112
# 131   40.76814100049679  -73.96387000158042
# 400   40.71256392680817  -74.00974461517701
# 72   40.739864000474604  -73.98659900207888
# 217   40.70491399928076  -74.01400799803432

# %%
float(d.split(' ')[2][:-1])
# Out:
# 40.71256392680817

# %%
ds5['lat'] = ds5['loc'].apply(lambda x: x.split(' ')[1][1:])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'loc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-436-ba364643cb61> in <module>()
# ----> 1 ds5['lat'] = ds5['loc'].apply(lambda x: x.split(' ')[1][1:])
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /usr/local/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'loc'

# %%
ds5['lon'] = ds5['loc'].apply(lambda x: x.split(' ')[2][:-1])

# %%
ds5.drop(['loc'],axis=1,inplace=True)

# %%
ds5
# Out:
#                      stl         idx  weekly_traffic  scaled_weekday_index  \
# 459           WALL ST 23  125.544063        122342.8              5.000000
# 108        5 AV/53 ST EM    9.026138        143383.8              3.610455
# 74              23 ST FM    8.880399        165668.6              3.552160
# 242    CHAMBERS ST ACE23    8.836013        168256.8              3.534405
# 105  47-50 STS ROCK BDFM    8.568578        324321.2              3.427431
# 241      CHAMBERS ST 123    8.364797        116794.0              3.345919
# 131     68ST-HUNTER CO 6    8.346565        123195.2              3.338626
# 400       PATH NEW WTC 1    7.894038        304638.6              3.157615
# 72               23 ST 6    7.878508        156331.0              3.151403
# 217     BOWLING GREEN 45    7.454063        169329.8              2.981625
#
#                    lat                 lon
# 459  74.00909999844257  40.706820999753376
# 108   73.9752485052734   40.76008683231326
# 74   73.99276500471389  40.742954317826005
# 242  74.00858473570133  40.714111000774025
# 105  73.98133100227702   40.75864100159815
# 241  74.00926600170112   40.71547800011327
# 131  73.96387000158042   40.76814100049679
# 400  74.00974461517701   40.71256392680817
# 72   73.98659900207888  40.739864000474604
# 217  74.01400799803432   40.70491399928076

# %%
loc
# Out:
#      OBJECTID                         NAME  \
# 0           1                     Astor Pl
# 1           2                     Canal St
# 2           3                      50th St
# 3           4                    Bergen St
# 4           5             Pennsylvania Ave
# 5           6                     238th St
# 6           7    Cathedral Pkwy (110th St)
# 7           8       Kingston - Throop Aves
# 8           9                      65th St
# 9          10                      36th St
# 10         11       Delancey St - Essex St
# 11         12               Van Siclen Ave
# 12         13                  Norwood Ave
# 13         14              104th-102nd Sts
# 14         15                   DeKalb Ave
# 15         16               Beach 105th St
# 16         17                Beach 90th St
# 17         18                   Freeman St
# 18         19                Intervale Ave
# 19         20              182nd-183rd Sts
# 20         21              174th-175th Sts
# 21         22                     167th St
# 22         23         Mets - Willets Point
# 23         24                Junction Blvd
# 24         25           Flushing - Main St
# 25         26                    Buhre Ave
# 26         27           3rd Ave - 138th St
# 27         28              Castle Hill Ave
# 28         29  Brooklyn Bridge - City Hall
# 29         30                   Zerega Ave
# ..        ...                          ...
# 443       444                      14th St
# 444       445                 Nostrand Ave
# 445       446                     Clark St
# 446       447                 Franklin Ave
# 447       448    Clinton - Washington Aves
# 448       449                   Forest Ave
# 449       450                     110th St
# 450       451                      86th St
# 451       452                      York St
# 452       453                      High St
# 453       454                Lafayette Ave
# 454       455                 President St
# 455       456                     Woodlawn
# 456       457                  Bleecker St
# 457       458                     103rd St
# 458       459                   Euclid Ave
# 459       460                      88th St
# 460       461                 Cortelyou Rd
# 461       462                     116th St
# 462       463                  Parkchester
# 463       464                  Franklin St
# 464       465                      80th St
# 465       466          5th Ave - Bryant Pk
# 466       467                    Spring St
# 467       468                     125th St
# 468       469  Coney Island - Stillwell Av
# 469       470       34th St - Hudson Yards
# 470       641                      72nd St
# 471       642                      86th St
# 472       643                      96th St
#
#                                           the_geom             LINE newline  \
# 0     POINT (-73.99106999861966 40.73005400028978)    4-6-6 Express      46
# 1     POINT (-74.00019299927328 40.71880300107709)    4-6-6 Express      46
# 2     POINT (-73.98384899986625 40.76172799961419)              1-2      12
# 3     POINT (-73.97499915116808 40.68086213682956)            2-3-4     234
# 4     POINT (-73.89488591154061 40.66471445143568)              3-4      34
# 5     POINT (-73.90087000018522 40.88466700064975)                1       1
# 6    POINT (-73.95806670661364 40.800581558114956)            A-B-C     ABC
# 7     POINT (-73.94085899871263 40.67991899941601)              A-C      AC
# 8      POINT (-73.8987883783301 40.74971952935675)            E-M-R     EMR
# 9     POINT (-73.92901818461539 40.75196004401078)            E-M-R     EMR
# 10    POINT (-73.98740940202974 40.71830605618619)            J-M-Z     JMZ
# 11    POINT (-73.89165772702445 40.67802821447783)              J-Z      JZ
# 12    POINT (-73.87962599910783 40.68152000045683)              J-Z      JZ
# 13    POINT (-73.84443500029684 40.69516599823373)              J-Z      JZ
# 14   POINT (-73.98177094440949 40.690648119969794)        B-D-N-Q-R   BDNQR
# 15    POINT (-73.82758075034528 40.58326843810286)              A-S      AS
# 16    POINT (-73.81365140419632 40.58809156457325)              A-S      AS
# 17   POINT (-73.89175225349464 40.829987446384116)              2-5      25
# 18   POINT (-73.89661738461646 40.822142131170786)              2-5      25
# 19    POINT (-73.90074099998965 40.85609299881864)              B-D      BD
# 20    POINT (-73.91013600050078 40.84589999983414)              B-D      BD
# 21    POINT (-73.91843200082253 40.83376899862797)              B-D      BD
# 22     POINT (-73.8456249984179 40.75462199881262)      7-7 Express       7
# 23    POINT (-73.86952700103515 40.74914499948836)      7-7 Express       7
# 24    POINT (-73.83003000262508 40.75959999915012)      7-7 Express       7
# 25   POINT (-73.83256900003744 40.846809998885504)      6-6 Express       6
# 26    POINT (-73.92613800014134 40.81047600117261)      6-6 Express       6
# 27    POINT (-73.85122199961472 40.83425499825462)      6-6 Express       6
# 28    POINT (-74.0041310005885 40.713064999433136)  4-5-6-6 Express     456
# 29    POINT (-73.8470359987544 40.836488000608156)      6-6 Express       6
# ..                                             ...              ...     ...
# 443  POINT (-74.00168999937027 40.740893000193296)            A-C-E     ACE
# 444    POINT (-73.9504262489579 40.66993815093054)              3-4      34
# 445   POINT (-73.99308599821961 40.69746599996469)              2-3      23
# 446   POINT (-73.95684800014614 40.68137966658742)              A-C      AC
# 447   POINT (-73.96583799857275 40.68326299912644)              A-C      AC
# 448   POINT (-73.90307500005954 40.70441200087814)                M       M
# 449  POINT (-73.94424999687163 40.795020000113105)    4-6-6 Express      46
# 450   POINT (-73.95558899985132 40.77949199820952)  4-5-6-6 Express     456
# 451  POINT (-73.98688499993673 40.699742667691574)                F       F
# 452   POINT (-73.99053100065458 40.69933699977884)              A-C      AC
# 453   POINT (-73.97394599849406 40.68611300020567)              A-C      AC
# 454  POINT (-73.95058920022207 40.667883603536815)              2-5      25
# 455  POINT (-73.87875099990931 40.886037000253324)                4       4
# 456   POINT (-73.99465900006331 40.72591466682659)    4-6-6 Express      46
# 457   POINT (-73.94747800152219 40.79060000008452)    4-6-6 Express      46
# 458  POINT (-73.87210600099675 40.675376998239365)            A-C-S     ACS
# 459   POINT (-73.85147000026086 40.67984300135503)              A-S      AS
# 460    POINT (-73.96379005505493 40.6409401651401)                Q       Q
# 461     POINT (-73.9416169983714 40.7986290002001)    4-6-6 Express      46
# 462   POINT (-73.86081600108396 40.83322599927859)      6-6 Express       6
# 463  POINT (-74.00688600277107 40.719318001302135)              1-2      12
# 464   POINT (-73.85899200206335 40.67937100115432)              A-S      AS
# 465   POINT (-73.98196299856706 40.75382100064824)      7-7 Express       7
# 466   POINT (-73.99714100006673 40.72230099999366)    4-6-6 Express      46
# 467  POINT (-73.93759400055725 40.804138000587244)  4-5-6-6 Express     456
# 468    POINT (-73.9812359981396 40.57728100006751)          D-F-N-Q    DFNQ
# 469   POINT (-74.00219709442206 40.75544635961596)      7-7 Express       7
# 470   POINT (-73.95836178682246 40.76880251014895)                Q       Q
# 471   POINT (-73.95177090964917 40.77786104333163)                Q       Q
# 472   POINT (-73.9470660219183 40.784236650177654)                Q       Q
#
#     newname
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# ..      ...
# 443     NaN
# 444     NaN
# 445     NaN
# 446     NaN
# 447     NaN
# 448     NaN
# 449     NaN
# 450     NaN
# 451     NaN
# 452     NaN
# 453     NaN
# 454     NaN
# 455     NaN
# 456     NaN
# 457     NaN
# 458     NaN
# 459     NaN
# 460     NaN
# 461     NaN
# 462     NaN
# 463     NaN
# 464     NaN
# 465     NaN
# 466     NaN
# 467     NaN
# 468     NaN
# 469     NaN
# 470     NaN
# 471     NaN
# 472     NaN
#
# [473 rows x 6 columns]
