# %%
import pandas as pd

subway = pd.read_csv('ScrubbedFirstDataSet.csv')

# %%
subway.head()
# Out:
#    Unnamed: 0   C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 0           0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/31/2018
# 1           1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/31/2018
# 2           2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/31/2018
# 3           3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/31/2018
# 4           4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/31/2018
#
#        TIME     DESC  ENTRIES    EXITS             datetime  4HR_Entries  \
# 0  00:00:00  REGULAR  6566463  2224050  2018-03-31 00:00:00          NaN
# 1  04:00:00  REGULAR  6566470  2224053  2018-03-31 04:00:00          7.0
# 2  08:00:00  REGULAR  6566470  2224053  2018-03-31 08:00:00          0.0
# 3  12:00:00  REGULAR  6566470  2224055  2018-03-31 12:00:00          0.0
# 4  16:00:00  REGULAR  6566470  2224055  2018-03-31 16:00:00          0.0
#
#    4HR_Exits
# 0        NaN
# 1        3.0
# 2        0.0
# 3        2.0
# 4        0.0

# %%
subway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196988 entries, 0 to 196987
# Data columns (total 15 columns):
# Unnamed: 0     196988 non-null int64
# C/A            196988 non-null object
# UNIT           196988 non-null object
# SCP            196988 non-null object
# STATION        196988 non-null object
# LINENAME       196988 non-null object
# DIVISION       196988 non-null object
# DATE           196988 non-null object
# TIME           196988 non-null object
# DESC           196988 non-null object
# ENTRIES        196988 non-null int64
# EXITS          196988 non-null int64
# datetime       196988 non-null object
# 4HR_Entries    192283 non-null float64
# 4HR_Exits      192283 non-null float64
# dtypes: float64(2), int64(3), object(10)
# memory usage: 22.5+ MB

# %%
a = subway[subway.STATION == '1 AV']

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 420 entries, 30139 to 30558
# Data columns (total 15 columns):
# Unnamed: 0     420 non-null int64
# C/A            420 non-null object
# UNIT           420 non-null object
# SCP            420 non-null object
# STATION        420 non-null object
# LINENAME       420 non-null object
# DIVISION       420 non-null object
# DATE           420 non-null object
# TIME           420 non-null object
# DESC           420 non-null object
# ENTRIES        420 non-null int64
# EXITS          420 non-null int64
# datetime       420 non-null object
# 4HR_Entries    410 non-null float64
# 4HR_Exits      410 non-null float64
# dtypes: float64(2), int64(3), object(10)
# memory usage: 52.5+ KB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(a.datetime, a.4HR_Entries);
# Out:
#   File "<ipython-input-8-6caa2bdbb6ee>", line 3
#     plt.plot(a.datetime, a.4HR_Entries);
#                            ^
# SyntaxError: invalid syntax

# %%
a['dt'] = pd.to_datetime(a['datetime'])
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41 entries, 0 to 40
# Data columns (total 6 columns):
# STATION           41 non-null object
# LINENAME          41 non-null object
# datetime          41 non-null object
# Hourly_Entries    41 non-null float64
# Hourly_Exits      41 non-null float64
# dt                41 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 2.2+ KB

# %%
a.head()
# Out:
#   STATION LINENAME             datetime  Hourly_Entries  Hourly_Exits  \
# 0    1 AV        L  2018-03-31 04:00:00          1359.0         937.0
# 1    1 AV        L  2018-03-31 08:00:00           471.0         928.0
# 2    1 AV        L  2018-03-31 12:00:00          2509.0        2810.0
# 3    1 AV        L  2018-03-31 16:00:00          4115.0        4228.0
# 4    1 AV        L  2018-03-31 20:00:00          4491.0        5512.0
#
#                    dt
# 0 2018-03-31 04:00:00
# 1 2018-03-31 08:00:00
# 2 2018-03-31 12:00:00
# 3 2018-03-31 16:00:00
# 4 2018-03-31 20:00:00

# %%
a.dt[0].weekday()
# Out:
# 5

# %%
a['weekday'] = a['dt'].apply(lambda x: x.weekday())
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
a_day = a.groupby(['STATION','LINENAME','weekday'])[['Hourly_Entries','Hourly_Exits']].sum()

# %%
a_day
# Out:
#                           Hourly_Entries  Hourly_Exits
# STATION LINENAME weekday
# 1 AV    L        0               17825.0       19505.0
#                  1               19463.0       22025.0
#                  2               20295.0       21976.0
#                  3               20759.0       22838.0
#                  4               21637.0       23235.0
#                  5               12945.0       14415.0
#                  6               13367.0       14932.0

# %%
a_day['daily_traiffic'] = a_day.Hourly_Entries +a_day.Hourly_Exits

# %%
a_day = a_day.reset_index()

# %%
def workday_index(df):
    for row in df
    weekend = 0
    weekday = 0
    if row['weekday'] < 5:
        weekday += row['daily_traffic']
    else:
        weekend += row['daily_traffic']
        
    index = weekday/weekend * 2/5
    return index

# %%
a_day.columns = ['STATION', 'LINENAME', 'weekday', 'Hourly_Entries', 'Hourly_Exits',
       'daily_traffic', 'is_weekday']

# %%
def is_weekday(row):
    if row < 5:
        return 1
    else: 
        return 0

# %%
a_day['is_weekday'] = a_day['weekday'].apply(is_weekday)

# %%
a_day.groupby(['is_weekday'])['daily_traffic'].mean()
# Out:
# 27829.5

# %%
subway['dt'] = pd.to_datetime(subway['datetime'])
subway['weekday'] = subway['dt'].apply(lambda x: x.weekday())
daily_subway = subway.groupby(['STATION','LINENAME','weekday'])[['Hourly_Entries','Hourly_Exits']].sum()

daily_subway['daily_traffic'] = daily_subway.Hourly_Entries + daily_subway.Hourly_Exits
daily_subway = daily_subway.reset_index()
daily_subway['is_weekday'] = daily_subway['weekday'].apply(is_weekday)

# %%
daily_subway.head()
# Out:
#   STATION LINENAME  weekday  Hourly_Entries  Hourly_Exits  daily_traiffic  \
# 0    1 AV        L        0         17825.0       19505.0         37330.0
# 1    1 AV        L        1         19463.0       22025.0         41488.0
# 2    1 AV        L        2         20295.0       21976.0         42271.0
# 3    1 AV        L        3         20759.0       22838.0         43597.0
# 4    1 AV        L        4         21637.0       23235.0         44872.0
#
#    is_weekday
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
daily_subway['stl'] = daily_subway['STATION'] + ' ' + daily_subway['LINENAME']

# %%
daily_subway.head()
# Out:
#   STATION LINENAME  weekday  Hourly_Entries  Hourly_Exits  daily_traiffic  \
# 0    1 AV        L        0         17825.0       19505.0         37330.0
# 1    1 AV        L        1         19463.0       22025.0         41488.0
# 2    1 AV        L        2         20295.0       21976.0         42271.0
# 3    1 AV        L        3         20759.0       22838.0         43597.0
# 4    1 AV        L        4         21637.0       23235.0         44872.0
#
#    is_weekday     stl
# 0           1  1 AV L
# 1           1  1 AV L
# 2           1  1 AV L
# 3           1  1 AV L
# 4           1  1 AV L

# %%
ds2 = daily_subway.groupby(['stl','is_weekday'])[['daily_traffic']].sum().reset_index()

# %%
ds2.head()
# Out:
#         stl  is_weekday  daily_traffic       idx
# 0    1 AV L           0        55659.0       NaN
# 1    1 AV L           1       209558.0  3.765034
# 2  103 ST 1           0        22372.0  0.106758
# 3  103 ST 1           1        90564.0  4.048096
# 4  103 ST 6           0        18203.0  0.200996

# %%
ds2['idx'] = ds2['daily_traffic']/ds2['daily_traffic'].shift(1)
ds2['weekly_traffic'] = ds2['daily_traffic'] + ds2['daily_traffic'].shift(1)

# %%
ds3 = ds2[ds2.is_weekday == 1]

# %%
ds3 = ds3[['stl','idx','weekly_traffic']].reset_index()

# %%
ds3= ds3[['stl','idx','weekly_traffic']]

# %%
ds3['scaled_weekday_index'] = ds3['idx']/2.5

# %%
ds3
# Out:
#                              stl          idx  weekly_traffic  \
# 0                         1 AV L     3.765034        265217.0
# 1                       103 ST 1     4.048096        112936.0
# 2                       103 ST 6     5.777674        123374.0
# 3                      103 ST BC     7.822340         38386.0
# 4                103 ST-CORONA 7     3.669575        199120.0
# 5                       104 ST A     5.598851         11482.0
# 6                      104 ST JZ     5.003188          5649.0
# 7                       110 ST 6     5.366306        104261.0
# 8                       111 ST 7     3.634896        108540.0
# 9                       111 ST A     6.671571         17729.0
# 10                      111 ST J     5.003285         23755.0
# 11                     116 ST 23   964.418919         71441.0
# 12                      116 ST 6     5.747045        121602.0
# 13                     116 ST BC     3.985439         54097.0
# 14             116 ST-COLUMBIA 1     5.618810        147295.0
# 15                     121 ST JZ     4.928791          9658.0
# 16                      125 ST 1     3.538128         93018.0
# 17                     125 ST 23   644.290076         84533.0
# 18                    125 ST 456     3.078044        276993.0
# 19                   125 ST ACBD     3.003719        318632.0
# 20                     135 ST 23  1372.650000         82419.0
# 21                     135 ST BC     5.258494         46050.0
# 22             137 ST CITY COL 1     3.854661        133008.0
# 23             138/GRAND CONC 45     4.134364         34544.0
# 24                  14 ST 123FLM     5.619489        173702.0
# 25                    14 ST ACEL     3.748875        200488.0
# 26                  14 ST FLM123     2.083385        271341.0
# 27       14 ST-UNION SQ 456LNQRW     4.079167        349147.0
# 28       14 ST-UNION SQ LNQR456W     4.765315        788966.0
# 29                      145 ST 1     3.531099        103300.0
# ..                           ...          ...             ...
# 441   TIMES SQ-42 ST 1237ACENQRS     3.310621        192258.0
# 442  TIMES SQ-42 ST 1237ACENQRSW     4.749690        750070.0
# 443  TIMES SQ-42 ST ACENQRS1237W     6.758911        213983.0
# 444              TOMPKINSVILLE 1     0.000161        105784.0
# 445                TREMONT AV BD     4.442626         87463.0
# 446            TWENTY THIRD ST 1     1.116214        183408.0
# 447                   UNION ST R     6.910096         65812.0
# 448                  UTICA AV AC     3.788316        165896.0
# 449             V.CORTLANDT PK 1     4.927913         59125.0
# 450              VAN SICLEN AV 3     4.848192         30896.0
# 451             VAN SICLEN AV JZ     4.161808         29923.0
# 452             VAN SICLEN AVE C     3.885042         33018.0
# 453             VERNON-JACKSON 7     4.790334        144133.0
# 454       W 4 ST-WASH SQ ABCDEFM     3.896326        497452.0
# 455           W 8 ST-AQUARIUM FQ     3.975792         24665.0
# 456              WAKEFIELD/241 2     4.071327         57306.0
# 457                   WALL ST 23  1255.632432        232477.0
# 458                   WALL ST 45     8.201259        194441.0
# 459             WEST FARMS SQ 25     4.409698         59128.0
# 460             WESTCHESTER SQ 6     5.419529         54765.0
# 461          WHITEHALL S-FRY R1W     5.437357        222121.0
# 462                WHITLOCK AV 6     0.226063         83425.0
# 463                  WILSON AV L     3.690023         50535.0
# 464               WINTHROP ST 25     6.652920         45466.0
# 465            WOODHAVEN BLVD JZ     4.572459         37837.0
# 466            WOODHAVEN BLVD MR     4.306856        177111.0
# 467                   WOODLAWN 4     4.936628         48057.0
# 468        WORLD TRADE CTR ACE23     0.901344        358601.0
# 469                    YORK ST F     4.544747         85439.0
# 470                  ZEREGA AV 6     5.660275         25702.0
#
#      scaled_weekday_index
# 0                1.506013
# 1                1.619238
# 2                2.311070
# 3                3.128936
# 4                1.467830
# 5                2.239540
# 6                2.001275
# 7                2.146523
# 8                1.453958
# 9                2.668628
# 10               2.001314
# 11             385.767568
# 12               2.298818
# 13               1.594176
# 14               2.247524
# 15               1.971516
# 16               1.415251
# 17             257.716031
# 18               1.231218
# 19               1.201488
# 20             549.060000
# 21               2.103398
# 22               1.541864
# 23               1.653746
# 24               2.247795
# 25               1.499550
# 26               0.833354
# 27               1.631667
# 28               1.906126
# 29               1.412440
# ..                    ...
# 441              1.324248
# 442              1.899876
# 443              2.703564
# 444              0.000064
# 445              1.777050
# 446              0.446485
# 447              2.764038
# 448              1.515326
# 449              1.971165
# 450              1.939277
# 451              1.664723
# 452              1.554017
# 453              1.916134
# 454              1.558530
# 455              1.590317
# 456              1.628531
# 457            502.252973
# 458              3.280504
# 459              1.763879
# 460              2.167812
# 461              2.174943
# 462              0.090425
# 463              1.476009
# 464              2.661168
# 465              1.828984
# 466              1.722742
# 467              1.974651
# 468              0.360537
# 469              1.817899
# 470              2.264110
#
# [471 rows x 4 columns]

# %%
ds3.to_csv('station_list.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.hist(ds3['weekly_traffic'])
# Out:
# (array([351.,  85.,  17.,   8.,   5.,   1.,   2.,   0.,   1.,   1.]),
#  array([1.3190000e+03, 1.6030820e+05, 3.1929740e+05, 4.7828660e+05,
#         6.3727580e+05, 7.9626500e+05, 9.5525420e+05, 1.1142434e+06,
#         1.2732326e+06, 1.4322218e+06, 1.5912110e+06]),
#  <a list of 10 Patch objects>)

# %%
high_traffic = ds3[ds3['weekly_traffic'] > 200000]

# %%
high_traffic.head()
# Out:
#              stl       idx  weekly_traffic  scaled_weekday_index
# 0         1 AV L  3.765034        265217.0              1.506013
# 18    125 ST 456  3.078044        276993.0              1.231218
# 19   125 ST ACBD  3.003719        318632.0              1.201488
# 25    14 ST ACEL  3.748875        200488.0              1.499550
# 26  14 ST FLM123  2.083385        271341.0              0.833354

# %%
plt.hist(high_traffic['weekly_traffic'])
# Out:
# (array([57., 15.,  8.,  4.,  2.,  2.,  0.,  1.,  0.,  1.]),
#  array([ 200488. ,  339560.3,  478632.6,  617704.9,  756777.2,  895849.5,
#         1034921.8, 1173994.1, 1313066.4, 1452138.7, 1591211. ]),
#  <a list of 10 Patch objects>)

# %%
high_traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90 entries, 0 to 468
# Data columns (total 4 columns):
# stl                     90 non-null object
# idx                     90 non-null float64
# weekly_traffic          90 non-null float64
# scaled_weekday_index    90 non-null float64
# dtypes: float64(3), object(1)
# memory usage: 3.5+ KB

# %%
high_traffic[high_traffic['scaled_weekday_index'] > 2]
# Out:
#                              stl          idx  weekly_traffic  \
# 71                       23 ST 6     7.037422        223585.0
# 72                      23 ST CE     5.093764        223568.0
# 73                      23 ST FM     9.858527        271246.0
# 74                     23 ST NRW     5.436194        216874.0
# 81                       28 ST 6     6.866358        246099.0
# 86                       33 ST 6     6.204273        290361.0
# 88      34 ST-HERALD SQ BDFMNQRW     6.092626       1298901.0
# 90            34 ST-PENN STA 123     8.108657        371114.0
# 91         34 ST-PENN STA 123ACE     5.463861        532202.0
# 98         42 ST-BRYANT PK BDFM7    10.669263        443502.0
# 104          47-50 STS ROCK BDFM    10.889540        667990.0
# 107                5 AV/53 ST EM     7.609060        317571.0
# 110                      50 ST 1     5.072393        293752.0
# 113                      51 ST 6     9.894801        239751.0
# 118              57 ST-7 AV NQRW     5.019339        268607.0
# 132                     7 AV BDE     7.825488        217663.0
# 142                      77 ST 6    10.085575        267506.0
# 174     ATL AV-BARCLAY 2345BDNQR     5.396700        230697.0
# 212           BOROUGH HALL 2345R     7.482552        300452.0
# 232                 CANAL ST ACE     5.151087        225708.0
# 241            CHAMBERS ST ACE23     7.719516        240554.0
# 262           CROWN HTS-UTICA 34     5.377625        236865.0
# 290         FOREST HILLS 71 EFMR     5.330692        220498.0
# 299           FULTON ST 2345ACJZ     7.491809        704956.0
# 300           FULTON ST ACJZ2345     5.443799        261876.0
# 309        GRD CNTRL-42 ST 4567S     7.671308       1591211.0
# 330           JAMAICA CENTER EJZ     5.632782        337403.0
# 332          JAY ST-METROTEC ACF     6.152198        317858.0
# 340               KEW GARDENS EF     6.254055        277308.0
# 351          LEXINGTON AV/53 EM6     8.939870        455087.0
# 440            THIRTY THIRD ST 1     7.041488        223674.0
# 443  TIMES SQ-42 ST ACENQRS1237W     6.758911        213983.0
# 457                   WALL ST 23  1255.632432        232477.0
# 461          WHITEHALL S-FRY R1W     5.437357        222121.0
#
#      scaled_weekday_index
# 71               2.814969
# 72               2.037505
# 73               3.943411
# 74               2.174478
# 81               2.746543
# 86               2.481709
# 88               2.437050
# 90               3.243463
# 91               2.185544
# 98               4.267705
# 104              4.355816
# 107              3.043624
# 110              2.028957
# 113              3.957921
# 118              2.007736
# 132              3.130195
# 142              4.034230
# 174              2.158680
# 212              2.993021
# 232              2.060435
# 241              3.087806
# 262              2.151050
# 290              2.132277
# 299              2.996724
# 300              2.177520
# 309              3.068523
# 330              2.253113
# 332              2.460879
# 340              2.501622
# 351              3.575948
# 440              2.816595
# 443              2.703564
# 457              3.000000
# 461              2.174943

# %%
plt.hist(high_traffic['scaled_weekday_index'])
# Out:
# (array([89.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([3.85522355e-02, 5.02599943e+01, 1.00481436e+02, 1.50702878e+02,
#         2.00924321e+02, 2.51145763e+02, 3.01367205e+02, 3.51588647e+02,
#         4.01810089e+02, 4.52031531e+02, 5.02252973e+02]),
#  <a list of 10 Patch objects>)

# %%
fix_high_traffic = high_traffic[high_traffic['scaled_weekday_index'] < 10]

# %%
plt.hist(fix_high_traffic['scaled_weekday_index'])
# Out:
# (array([13.,  8.,  7., 22., 17.,  5.,  8.,  4.,  1.,  5.]),
#  array([0.03855224, 0.47027859, 0.90200495, 1.33373131, 1.76545767,
#         2.19718403, 2.62891038, 3.06063674, 3.4923631 , 3.92408946,
#         4.35581582]),
#  <a list of 10 Patch objects>)
